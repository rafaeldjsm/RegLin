# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaeldjsm/RegLin/blob/master/GDAvIM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
# -*- coding: utf-8 -*-
#Use to import pandas
import pandas as pd
import numpy as np
#Use to import the file into google Colab drive
from google.colab import files
df = pd.read_csv('/content/drive/My Drive/Dados.csv',encoding='latin1')
df=df.drop(columns=['Dado'])
dm=df.T
nl=dm.shape
nl = nl[1]

# Definir vetor/lista com:
vet = []; # define um vetor vazio
for i in range(0, nl, 1) : # ou mais simples neste caso "for i in range(n)"
  vet.append(int(1)); # anexe mais um elemento `a lista
# Imprime o vetor/lista de uma so' vez (na mesma linha)

vet=(pd.DataFrame(vet)).T

md=pd.concat([vet, dm])
md=md.drop(columns=[nl-1])
mdt=md.T
mdt
# Out:
#     0  Andar  ... Posição do Imóvel no Terreno Valor Total (R$)
# 0   1   7,00  ...                         3,00       125.000,00
# 1   1   5,00  ...                         3,00        95.000,00
# 2   1   5,00  ...                         2,00       150.000,00
# 3   1  11,00  ...                         3,00        75.000,00
# 4   1  11,00  ...                         2,00        85.000,00
# 5   1   9,00  ...                         3,00        50.000,00
# 6   1  13,00  ...                         3,00        60.000,00
# 7   1   2,00  ...                         1,00       950.000,00
# 8   1   4,00  ...                         1,00       350.000,00
# 9   1  10,00  ...                         3,00        60.000,00
# 10  1  13,00  ...                         3,00        50.000,00
# 11  1   6,00  ...                         1,00        55.000,00
# 12  1  12,00  ...                         1,00       270.000,00
# 13  1   9,00  ...                         3,00        60.000,00
# ...

# %%
CI=md.dot(mdt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f01cb31c8efb> in <module>()
# ----> 1 CI=md.dot(mdt)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in dot(self, other)
#    1094         if isinstance(other, DataFrame):
#    1095             return self._constructor(
# -> 1096                 np.dot(lvals, rvals), index=left.index, columns=other.columns
#    1097             )
#    1098         elif isinstance(other, Series):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# TypeError: can't multiply sequence by non-int of type 'str'
